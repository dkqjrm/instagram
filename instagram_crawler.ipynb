# %%
# !pip install bs4
# !pip install lxml
# !pip install selenium
# !pip install requests
# !pip install tqdm
# !pip install slackclient==1.0.7
# Out:
# Requirement already satisfied: bs4 in /Users/hyun/miniforge3/envs/tf25/lib/python3.8/site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in /Users/hyun/miniforge3/envs/tf25/lib/python3.8/site-packages (from bs4) (4.10.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/hyun/miniforge3/envs/tf25/lib/python3.8/site-packages (from beautifulsoup4->bs4) (2.3.1)
# Requirement already satisfied: lxml in /Users/hyun/miniforge3/envs/tf25/lib/python3.8/site-packages (4.7.1)
# Requirement already satisfied: selenium in /Users/hyun/miniforge3/envs/tf25/lib/python3.8/site-packages (4.1.0)
# Requirement already satisfied: trio~=0.17 in /Users/hyun/miniforge3/envs/tf25/lib/python3.8/site-packages (from selenium) (0.19.0)
# Requirement already satisfied: urllib3[secure]~=1.26 in /Users/hyun/miniforge3/envs/tf25/lib/python3.8/site-packages (from selenium) (1.26.8)
# Requirement already satisfied: trio-websocket~=0.9 in /Users/hyun/miniforge3/envs/tf25/lib/python3.8/site-packages (from selenium) (0.9.2)
# Requirement already satisfied: outcome in /Users/hyun/miniforge3/envs/tf25/lib/python3.8/site-packages (from trio~=0.17->selenium) (1.1.0)
# Requirement already satisfied: sortedcontainers in /Users/hyun/miniforge3/envs/tf25/lib/python3.8/site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: async-generator>=1.9 in /Users/hyun/miniforge3/envs/tf25/lib/python3.8/site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: attrs>=19.2.0 in /Users/hyun/miniforge3/envs/tf25/lib/python3.8/site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: sniffio in /Users/hyun/miniforge3/envs/tf25/lib/python3.8/site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: idna in /Users/hyun/miniforge3/envs/tf25/lib/python3.8/site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: wsproto>=0.14 in /Users/hyun/miniforge3/envs/tf25/lib/python3.8/site-packages (from trio-websocket~=0.9->selenium) (1.0.0)
# Requirement already satisfied: cryptography>=1.3.4 in /Users/hyun/miniforge3/envs/tf25/lib/python3.8/site-packages (from urllib3[secure]~=1.26->selenium) (36.0.1)
# Requirement already satisfied: certifi in /Users/hyun/miniforge3/envs/tf25/lib/python3.8/site-packages (from urllib3[secure]~=1.26->selenium) (2021.10.8)
# Requirement already satisfied: pyOpenSSL>=0.14 in /Users/hyun/miniforge3/envs/tf25/lib/python3.8/site-packages (from urllib3[secure]~=1.26->selenium) (21.0.0)
# Requirement already satisfied: cffi>=1.12 in /Users/hyun/miniforge3/envs/tf25/lib/python3.8/site-packages (from cryptography>=1.3.4->urllib3[secure]~=1.26->selenium) (1.15.0)
# Requirement already satisfied: six>=1.5.2 in /Users/hyun/miniforge3/envs/tf25/lib/python3.8/site-packages (from pyOpenSSL>=0.14->urllib3[secure]~=1.26->selenium) (1.15.0)
# Requirement already satisfied: h11<1,>=0.9.0 in /Users/hyun/miniforge3/envs/tf25/lib/python3.8/site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.13.0)
# Requirement already satisfied: pycparser in /Users/hyun/miniforge3/envs/tf25/lib/python3.8/site-packages (from cffi>=1.12->cryptography>=1.3.4->urllib3[secure]~=1.26->selenium) (2.21)
# Requirement already satisfied: requests in /Users/hyun/miniforge3/envs/tf25/lib/python3.8/site-packages (2.27.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/hyun/miniforge3/envs/tf25/lib/python3.8/site-packages (from requests) (2.0.10)
# Requirement already satisfied: idna<4,>=2.5 in /Users/hyun/miniforge3/envs/tf25/lib/python3.8/site-packages (from requests) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/hyun/miniforge3/envs/tf25/lib/python3.8/site-packages (from requests) (1.26.8)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/hyun/miniforge3/envs/tf25/lib/python3.8/site-packages (from requests) (2021.10.8)
# Requirement already satisfied: tqdm in /Users/hyun/miniforge3/envs/tf25/lib/python3.8/site-packages (4.62.3)
# Requirement already satisfied: slackclient==1.0.7 in /Users/hyun/miniforge3/envs/tf25/lib/python3.8/site-packages (1.0.7)
# Requirement already satisfied: websocket-client<1.0a0,>=0.35 in /Users/hyun/miniforge3/envs/tf25/lib/python3.8/site-packages (from slackclient==1.0.7) (0.59.0)
# Requirement already satisfied: six<2.0a0,>=1.10 in /Users/hyun/miniforge3/envs/tf25/lib/python3.8/site-packages (from slackclient==1.0.7) (1.15.0)
# Requirement already satisfied: requests<3.0a0,>=2.11 in /Users/hyun/miniforge3/envs/tf25/lib/python3.8/site-packages (from slackclient==1.0.7) (2.27.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/hyun/miniforge3/envs/tf25/lib/python3.8/site-packages (from requests<3.0a0,>=2.11->slackclient==1.0.7) (2.0.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/hyun/miniforge3/envs/tf25/lib/python3.8/site-packages (from requests<3.0a0,>=2.11->slackclient==1.0.7) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/hyun/miniforge3/envs/tf25/lib/python3.8/site-packages (from requests<3.0a0,>=2.11->slackclient==1.0.7) (1.26.8)
# Requirement already satisfied: idna<4,>=2.5 in /Users/hyun/miniforge3/envs/tf25/lib/python3.8/site-packages (from requests<3.0a0,>=2.11->slackclient==1.0.7) (3.3)

# %%
from selenium.webdriver.common.keys import Keys
import datetime
import re
import tqdm
from selenium import webdriver
import time
from bs4 import BeautifulSoup
from selenium.webdriver.common.by import By
import random
import math
import requests
import pandas as pd
from selenium.common.exceptions import NoSuchElementException as NSEE
import re
from slackclient import SlackClient
import os
from urllib.request import urlopen

# %%
slack_token = 'xoxb-3058701605317-3266962821889-nHCTSyaRNIXBDJuE1SxHtcnT' #발급 받은 토큰
sc = SlackClient(slack_token)
    
    #메세지 전달
def notification(message):
    sc.api_call(
        "chat.postMessage",
        channel="#인스타그램", #{#채널}의 형태로 채널 지정
        text=message
    )
# notification('안녕')

# %%
chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument('--headless')  # 브라우저 창을 띄우지 않는 옵션
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-dev-shm-usage')
chrome_options.add_argument(
    'user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.71 Safari/537.36')  # headless 옵션으로 서버에서 차단당하지 않기위해 넣는 옵션
# driver = webdriver.Chrome('C:/Users/brain/Desktop/crawling/code/chromedriver.exe', options=chrome_options) # 입력


driver = webdriver.Chrome('./chromedriver.exe')  # chrome driver 입력
driver.implicitly_wait(30)
_keyword = 'beauty' # 검색할 키워드
url = 'https://www.instagram.com/explore/tags/'+_keyword
# url = 'https://www.instagram.com/explore/tags/cat/'
driver.get(url)
driver.implicitly_wait(30)
time.sleep(4)

try:
    driver.find_element(By.XPATH, '//*[@id="react-root"]/section/nav/div[2]/div/div/div[3]/div/span/a[1]/button').click()
except:
    print("하..")
# Out:
# /var/folders/2x/h2z3m2816w39tgg6fjsqp8l00000gn/T/ipykernel_67965/1988164067.py:10: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('./chromedriver')  # chrome driver 입력
# 하..

# %%
def login():  # 로그인
    driver.find_element(By.XPATH, '//*[@id="loginForm"]/div/div[1]/div/label/input').click()
    driver.find_element(By.XPATH, '//*[@id="loginForm"]/div/div[1]/div/label/input').send_keys('nlpsumin')  # ID
    driver.find_element(By.XPATH, '//*[@id="loginForm"]/div/div[2]/div/label/input').click()
    driver.find_element(By.XPATH, '//*[@id="loginForm"]/div/div[2]/div/label/input').send_keys('nlpsumin2022')  # PWD
    driver.find_element(By.XPATH, '//*[@id="loginForm"]/div/div[3]/button').click()
    time.sleep(5)
    driver.find_element(By.XPATH, '//*[@id="react-root"]/section/main/div/div/div/div/button').click()
    # pyautogui.click(472, 642)
    time.sleep(5)


#     pyautogui.click(487, 719)
#     time.sleep(5)

# %%
time.sleep(3)
login()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [27], in <module>
#       1 time.sleep(3)
# ----> 2 login()
#
# Input In [26], in login()
#       6 driver.find_element(By.XPATH, '//*[@id="loginForm"]/div/div[3]/button').click()
#       7 time.sleep(5)
# ----> 8 driver.find_element(By.XPATH, '//*[@id="react-root"]/section/main/div/div/div/div/button').click()
#       9 # pyautogui.click(472, 642)
#      10 time.sleep(5)
#
# AttributeError: 'NoneType' object has no attribute 'click'

# %%
#driver.find_element(By.XPATH, '//*[@id="react-root"]/section/main/article/div[1]/div/div/div[1]/div[1]/a/div/div[2]').click()
driver.find_element_by_css_selector('div.v1Nh3.kIKUG._bz0w').click() #첫번째 게시물 열기
time.sleep(5)
# Out:
# /var/folders/2x/h2z3m2816w39tgg6fjsqp8l00000gn/T/ipykernel_67965/281526141.py:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_css_selector('div.v1Nh3.kIKUG._bz0w').click() #첫번째 게시물 열기

# %%
regex = re.compile("["
        "a-z"
        "A-Z"
        "0-9"
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"# flags (iOS)
                   " "
                   " "
                   '⠀'
                   "\0020"
                   "-=+,#/\?:^$.@*\"※~&%ㆍ!』\\‘|\(\)\[\]\<\>`\'…：_·"
                   "’♥"
                   "③②①•♡‥←」「„”“،～}{？。、）（！ 　้"
                   "\ufe0f"
                   "\n"
                   "주수정됨분시간일월"
                           "]+", flags=re.UNICODE)

# %%
all = []
exc = set()
count = 800 # 몇개의 게시물을 할건지
for i in tqdm.tqdm(range(count)):
    check = 1
    try:
        hashtags = []
        sources = []
        image_list = []
      # 올린사람 ID
        try:
            upload_id_object = driver.find_element(By.XPATH, '/html/body/div[6]/div[3]/div/article/div/div[2]/div/div/div[1]/div/header/div[2]/div[1]/div[1]/div/span/a')
            upload_id = upload_id_object.text
        except:
            upload_id = None

        for j in all:
            if upload_id in j:
                check = 0
                break
        if(check == 0):
            time.sleep(60)
            next_arrow_btn = driver.find_element_by_css_selector("div.l8mY4.feth3 > .wpO6b ") #다음 게시물로 이동
            next_arrow_btn.send_keys(Keys.ENTER)
            continue

    
        #해시태그
        try:
            data = driver.find_elements_by_css_selector('a.xil3i') # 해쉬태그 정보 저장
            for j in range(len(data)):
                hashtags.append(data[j].text.replace("#","")) # '#'없애기
            contents_html = driver.page_source
            contents_bs = BeautifulSoup(contents_html, 'lxml')
            contents = contents_bs.find('div', {'class', 'C4VMK'}).get_text()
            for k in contents:
                if regex.findall(k) == []:
                    check = 0
                    exc.add(k)
            if check == 0:
                time.sleep(60)
                next_arrow_btn = driver.find_element_by_css_selector("div.l8mY4.feth3 > .wpO6b ") #다음 게시물로 이동
                next_arrow_btn.send_keys(Keys.ENTER)
                continue
        except:
            print("해시태그 저장 실패"+str(i))
  
     # 이미지

        overlapphoto = driver.find_elements_by_class_name("Yi5aA")
        if (len(overlapphoto) == 0):
            try:
                image = driver.find_element_by_css_selector('div._97aPb.C2dOX   img.FFVAD')
                images = image.get_attribute('src')
                image_list.append(images)
            except:
                images = "error"
                print("이미지 저장 실패"+str(i))
        else :
            for n in range(len(overlapphoto)):
                try:
                    image = driver.find_elements_by_css_selector('div._97aPb.C2dOX   img.FFVAD')
                    for l in image:
                        images = l.get_attribute('src')
                        if images not in image_list:
                            image_list.append(images)
                except:
                    images = "error"
                    print("이미지 저장 실패"+str(i))
                try :
                    driver.find_element_by_class_name("coreSpriteRightChevron").click()
                    time.sleep(4)
                except :
                    break

        # 위치정보
        try:
            location_object = driver.find_element(By.XPATH, '/html/body/div[6]/div[3]/div/article/div/div[2]/div/div/div[1]/div/header/div[2]/div[2]/div/div[2]/div/a')
            location_info = location_object.text
            location_href = location_object.get_attribute("href")
        except:
            location_info = None
            location_href = None




        # 날짜
        try:
            date_object = driver.find_element(By.XPATH, '/html/body/div[6]/div[3]/div/article/div/div[2]/div/div/div[2]/div[1]/ul/div/li/div/div/div[2]/div[2]/div/time')
            date_text = date_object.text
            date_time = date_object.get_attribute("datetime")
            date_title = date_object.get_attribute("title")
        except:
            date_text = None
            date_time = None
            date_title = None
        

        
            
        all.append([upload_id,date_time,hashtags,contents,image_list,location_info,location_href])
        
        if (i+1)%10 == 0: 
            print('{}번째 게시물 완료'.format(i+1))
            df = pd.DataFrame(all,columns=["upload_id","date_time","hashtags","contents","images","location_info","location_href"])
            filename = datetime.datetime.now().strftime("%m월 %d일 %H시%M분")
            df.to_csv(_keyword+filename+".csv",encoding="UTf-8-sig")
        print("성공한 사진의 수"+str(len(all)))
        if(len(all) % 20 == 0) :
            notification(_keyword+'의 crawling이'+str(len(all))+'개 진행되었습니다.')
        next_arrow_btn = driver.find_element_by_css_selector("div.l8mY4.feth3 > .wpO6b ") #다음 게시물로 이동
        next_arrow_btn.send_keys(Keys.ENTER)
        
        time.sleep(3)
        
    except AttributeError:
        print("pass"+str(i))
        next_arrow_btn = driver.find_element_by_css_selector("div.l8mY4.feth3 > .wpO6b ") #다음 게시물로 이동
        next_arrow_btn.send_keys(Keys.ENTER)
        continue

df = pd.DataFrame(all,columns=["upload_id","date_time","hashtags","contents","images","location_info","location_href"])
filename = datetime.datetime.now().strftime("%m월 %d일 %H시%M분")
df.to_csv(_keyword+filename+".csv",encoding="utf-8-sig")

os.mkdir(_keyword)
df = pd.read_csv("./"+_keyword+filename+".csv",encoding="utf-8-sig")
for i, texts in enumerate(df['images']):
    images = texts.split(',')
    for j in range(len(images)):
        image = images[j][2:-2]
        try:
            print(image)
            with urlopen(image) as f:
                with open('./' + _keyword+'/' + str(i) + '-' + str(j) + '.jpg','wb') as h:
                    img = f.read()
                    h.write(img)
        except:
            continue
# Out:
#   0%|                                                     | 0/3 [00:00<?, ?it/s]/var/folders/2x/h2z3m2816w39tgg6fjsqp8l00000gn/T/ipykernel_67965/2538444115.py:30: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   data = driver.find_elements_by_css_selector('a.xil3i') # 해쉬태그 정보 저장
# /var/folders/2x/h2z3m2816w39tgg6fjsqp8l00000gn/T/ipykernel_67965/2538444115.py:50: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   overlapphoto = driver.find_elements_by_class_name("Yi5aA")
# /var/folders/2x/h2z3m2816w39tgg6fjsqp8l00000gn/T/ipykernel_67965/2538444115.py:62: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   image = driver.find_elements_by_css_selector('div._97aPb.C2dOX   img.FFVAD')
# /var/folders/2x/h2z3m2816w39tgg6fjsqp8l00000gn/T/ipykernel_67965/2538444115.py:71: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_class_name("coreSpriteRightChevron").click()
# 성공한 사진의 수1
# /var/folders/2x/h2z3m2816w39tgg6fjsqp8l00000gn/T/ipykernel_67965/2538444115.py:112: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   next_arrow_btn = driver.find_element_by_css_selector("div.l8mY4.feth3 > .wpO6b ") #다음 게시물로 이동
#  33%|███████████████                              | 1/3 [00:57<01:55, 57.65s/it]/var/folders/2x/h2z3m2816w39tgg6fjsqp8l00000gn/T/ipykernel_67965/2538444115.py:23: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   next_arrow_btn = driver.find_element_by_css_selector("div.l8mY4.feth3 > .wpO6b ") #다음 게시물로 이동
# 100%|█████████████████████████████████████████████| 3/3 [02:58<00:00, 59.56s/it]

# %%
df = pd.DataFrame(all,columns=["upload_id","date_time","hashtags","contents","images","location_info","location_href"])

# %%
df.to_csv(_keyword+".csv",encoding="utf-8-sig")

# %%
df = pd.read_csv(_keyword+".csv",encoding="utf-8-sig")
for i, texts in enumerate(df['images']):
    images = texts.split(',')
    for j in range(len(images)):
        image = images[j][2:-2]
        try:
            print(image)
            with urlopen(image) as f:
                with open('./' + _keyword+'/' + str(i) + '-' + str(j) + '.jpg','wb') as h:
                    img = f.read()
                    h.write(img)
        except:
            continue
    # print(i,images)
# Out:
# https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-15